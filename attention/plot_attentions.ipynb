# %%
import numpy as np
import pandas as pd

# %%
csv_file = "../data/LargeRandNet/LargeRandNet_ConnWeight.csv"
conn = np.array(pd.read_csv(csv_file, header=None))
# conn = np.load(csv_file, allow_pickle=True)

# %%
conn.shape
# Out:
# (1000, 1000)

# %%
import matplotlib.pyplot as plt
path = "../models/tensorboard/LRN/channel/2_window:0.5_prev:19.5/sparse_f:None_id:None/w:0.5_wp:19.5/attentions/6_att_matrix_gradcam_False.npy"
att_conn = np.load(path, allow_pickle=True)
plt.title("Real Conn")
plt.imshow(conn)

# %%
# normalize each row
att_conn_mean = att_conn / att_conn.sum(axis=1, keepdims=True)

# %%
y = np.arange(len(att_conn))
x = y

plt.title("Att Conn")
plt.matshow(att_conn)
plt.plot(x, y, color="red", lw=1, ls="--")

plt.figure()
plt.title("Att Conn Mean")
plt.matshow(att_conn_mean)
plt.plot(x, y, color="red", lw=1, ls="--")


plt.figure()
plt.plot(x, y, color="red", lw=1, ls="--")
plt.matshow(conn, cmap="gray", alpha=0.5)
